# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(15)
years = ['플랫폼', '기술', '기업', '게임', '투자', '시장', '글로벌', '디지털', '내년', '사업', '서비스', '가상',' 활용', '미국', '개발']
values = [650, 634, 579, 526, 522, 403, 378, 361, 361, 358, 324, 318, 316, 304, 296]

plt.title('2021년 단어 빈도수')
plt.xlabel('단어')
plt.ylabel('빈도 수')
plt.bar(x, values)
plt.xticks(x, years)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(15)
years = ['서비스', '콘텐츠', '기술', '글로벌', '플랫폼', '협력', '기업', '제공', '산업', '게임', '텔레콤', '사업', '개발', '활용', '분야']
values = [663, 651, 597, 497, 427, 392, 390, 367, 328, 324, 322, 322, 314, 288, 273]

plt.title('2022년 단어 빈도수')
plt.xlabel('단어')
plt.ylabel('빈도 수')
plt.bar(x, values)
plt.xticks(x, years)

plt.show()

plt.savefig('2022년_bar.png')
